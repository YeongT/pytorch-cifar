# %%
# !git clone https://github.com/kuangliu/pytorch-cifar.git
# Out:
# Cloning into 'pytorch-cifar'...
# remote: Enumerating objects: 382, done.
# remote: Total 382 (delta 0), reused 0 (delta 0), pack-reused 382 (from 1)
# Receiving objects: 100% (382/382), 94.67 KiB | 6.31 MiB/s, done.
# Resolving deltas: 100% (182/182), done.

# %%
# %cd pytorch-cifar
# Out:
# /kaggle/working/pytorch-cifar

# %%
# !pwd
# !ls
# Out:
# /kaggle/working/pytorch-cifar
# LICENSE  main.py  models  README.md  utils.py

# %%
import torch
print(torch.cuda.is_available())  # True가 나와야 함
print(torch.cuda.get_device_name(0)) # Tesla P100... 이라고 떠야 함
# Out:
# True
# Tesla P100-PCIE-16GB

# %%
# !python main.py --epochs 30 --batch_size 256 --num_workers 4
# Out:
# usage: main.py [-h] [--lr LR] [--resume]
# main.py: error: unrecognized arguments: --epochs 30 --batch_size 256 --num_workers 4
