# %%
# !git clone https://github.com/YeongT/pytorch-cifar.git
# Out:
# Cloning into 'pytorch-cifar'...
# remote: Enumerating objects: 384, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 384 (delta 6), reused 4 (delta 1), pack-reused 368 (from 2)
# Receiving objects: 100% (384/384), 53.80 MiB | 21.75 MiB/s, done.
# Resolving deltas: 100% (174/174), done.

# %%
# %cd pytorch-cifar
# Out:
# /kaggle/working/pytorch-cifar

# %%
# !pwd
# !ls
# Out:
# /kaggle/working/pytorch-cifar
# checkpoint   inference.py  main.py  README.md	      utils.py
# cifar.ipynb  LICENSE	   models   requirements.txt

# %%
import torch
print(torch.cuda.is_available())  # True가 나와야 함
print(torch.cuda.get_device_name(0)) # Tesla P100... 이라고 떠야 함
# Out:
# True
# Tesla P100-PCIE-16GB

# %%
# !python main.py --epochs 30 --batch_size 256 --num_workers 4
# Out:
# ==> Preparing data..
# 100%|████████████████████████████████████████| 170M/170M [00:13<00:00, 13.0MB/s]
# ==> Building model..
#
# Epoch: 0
# /kaggle/working/pytorch-cifar/main.py:120: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_amp):
#  196/196
# /kaggle/working/pytorch-cifar/main.py:159: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_amp):
#  100/100
# Saving..
#
# Epoch: 1
#  196/196
#  100/100
# Saving..
#
# Epoch: 2
#  196/196
#  100/100
# Saving..
#
# Epoch: 3
#  196/196
#  100/100
# Saving..
#
# Epoch: 4
#  196/196
#  100/100
# Saving..
#
# Epoch: 5
#  196/196
#  100/100
# Saving..
#
# Epoch: 6
#  196/196
#  100/100
# Saving..
#
# Epoch: 7
#  196/196
#  100/100
#
# Epoch: 8
#  196/196
#  100/100
# Saving..
#
# Epoch: 9
#  196/196
#  100/100
# Saving..
#
# Epoch: 10
#  196/196
#  100/100
# Saving..
#
# Epoch: 11
#  196/196
#  100/100
# Saving..
#
# Epoch: 12
#  196/196
#  100/100
#
# Epoch: 13
#  196/196
#  100/100
# Saving..
#
# Epoch: 14
#  196/196
#  100/100
#
# Epoch: 15
#  196/196
#  100/100
# Saving..
#
# Epoch: 16
#  196/196
#  100/100
# Saving..
#
# Epoch: 17
#  196/196
#  100/100
# Saving..
#
# Epoch: 18
#  196/196
#  100/100
# Saving..
#
# Epoch: 19
#  196/196
#  100/100
#
# Epoch: 20
#  196/196
#  100/100
# Saving..
#
# Epoch: 21
#  196/196
#  100/100
# Saving..
#
# Epoch: 22
#  196/196
#  100/100
#
# Epoch: 23
#  196/196
#  100/100
# Saving..
#
# Epoch: 24
#  196/196
#  100/100
# Saving..
#
# Epoch: 25
#  196/196
#  100/100
# Saving..
#
# Epoch: 26
#  196/196
#  100/100
# Saving..
#
# Epoch: 27
#  196/196
#  100/100
# Saving..
#
# Epoch: 28
#  196/196
#  100/100
# Saving..
#
# Epoch: 29
#  196/196
#  100/100
